# %% [raw]
# Timestamp: Dấu thời gian ghi lại khi người tham gia hoàn thành khảo sát.
#
# Age: Tuổi của người tham gia.
#
# Gender: Giới tính của người tham gia.
#
# Country: Quốc gia nơi người tham gia sinh sống.
#
# state: Nếu sống tại Hoa Kỳ, đây là bang hoặc lãnh thổ mà người tham gia đang cư trú.
#
# self_employed: Người tham gia có làm việc tự do (tự kinh doanh) hay không.
#
# family_history: Người tham gia có tiền sử gia đình mắc bệnh tâm lý hay không.
#
# treatment: Người tham gia có từng tìm kiếm điều trị cho các vấn đề về sức khỏe tâm lý hay không.
#
# work_interfere: Nếu người tham gia có vấn đề sức khỏe tâm lý, liệu nó có ảnh hưởng đến công việc của họ không.
#
# no_employees: Quy mô công ty hoặc tổ chức nơi người tham gia làm việc (dựa trên số lượng nhân viên).
#
# remote_work: Người tham gia có làm việc từ xa (ngoài văn phòng) ít nhất 50% thời gian hay không.
#
# tech_company: Công ty mà người tham gia làm việc có phải là công ty/cơ quan công nghệ không.
#
# benefits: Công ty có cung cấp các lợi ích liên quan đến sức khỏe tâm lý hay không.
#
# care_options: Người tham gia có biết về các lựa chọn chăm sóc sức khỏe tâm lý do công ty cung cấp hay không.
#
# wellness_program: Công ty có từng thảo luận về sức khỏe tâm lý trong chương trình phúc lợi nhân viên không.
#
# seek_help: Công ty có cung cấp tài nguyên để tìm hiểu và hỗ trợ về sức khỏe tâm lý không.
#
# anonymity: Liệu danh tính của người tham gia có được bảo mật khi sử dụng các tài nguyên liên quan đến sức khỏe tâm lý hoặc điều trị lạm dụng chất kích thích hay không.
#
# leave: Độ dễ dàng khi người tham gia xin nghỉ phép vì lý do sức khỏe tâm lý.
#
# mental_health_consequence: Người tham gia có nghĩ rằng thảo luận về vấn đề sức khỏe tâm lý với công ty sẽ gây ra hậu quả tiêu cực hay không.
#
# phys_health_consequence: Người tham gia có nghĩ rằng thảo luận về vấn đề sức khỏe thể chất với công ty sẽ gây ra hậu quả tiêu cực hay không.
#
# coworkers: Người tham gia có sẵn sàng thảo luận về vấn đề sức khỏe tâm lý với đồng nghiệp hay không.
#
# supervisor: Người tham gia có sẵn sàng thảo luận về vấn đề sức khỏe tâm lý với quản lý trực tiếp hay không.
#
# mental_health_interview: Người tham gia có sẵn sàng đề cập đến vấn đề sức khỏe tâm lý với nhà tuyển dụng tiềm năng trong buổi phỏng vấn hay không.
#
# phys_health_interview: Người tham gia có sẵn sàng đề cập đến vấn đề sức khỏe thể chất với nhà tuyển dụng tiềm năng trong buổi phỏng vấn hay không.
#
# mental_vs_physical: Người tham gia có cảm thấy rằng công ty coi trọng sức khỏe tâm lý ngang bằng với sức khỏe thể chất hay không.
#
# obs_consequence: Người tham gia có từng nghe về hoặc chứng kiến hậu quả tiêu cực đối với đồng nghiệp có vấn đề sức khỏe tâm lý tại nơi làm việc không.
#
# comments: Bất kỳ ghi chú hoặc bình luận bổ sung nào mà người tham gia muốn chia sẻ.
#
# có các giá trị null ở các cột:
#  4   state                      744 non-null    object: Là các Quốc gia khác Mỹ, nên không có bang-> không được xóa
#  5   self_employed              1241 non-null   object: Thay thế bằng giá trị có tần suất cao nhất
#  8   work_interfere             995 non-null    object: Thay thế bằng giá trị có tần suất cao nhất
#  26  comments                   164 non-null    object: Xóa cột vì số lượng null quá nhiều và không ảnh hưởng xâu sắc tới dữ liệu
#
# các cột cần chuẩn hóa, làm sạch:
# Gender                         49: 'Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'
# no_employees                    6: '6-25', 'More than 1000', '26-100', '100-500', '1-5', '500-1000'
# comments                      160: Xóa cột
